# %%
# create full 2.99 million dataframe with shortened column dimension (29)
# import libraries, load csv to DF
import pandas as pd
import csv
csvfile = ("zillowDF2017trunc_out.csv")
zwDF2017Short= pd.read_csv(csvfile)
zwDF2017Short.head()
# Out:
#    parcelid  ac_type  bath  beds  bldg_qual  calc_bath  sqft  calc_sqft  \
# 0  10754147      NaN   0.0   0.0        NaN        NaN   NaN        NaN
# 1  10759547      NaN   0.0   0.0        NaN        NaN   NaN        NaN
# 2  10843547      NaN   0.0   0.0        NaN        NaN   NaN    73026.0
# 3  10859147      NaN   0.0   0.0        6.0        NaN   NaN     5068.0
# 4  10879947      NaN   0.0   0.0        NaN        NaN   NaN     1776.0
#
#      fips  garage    ...      rooms  units  yearbuilt  tax_structure  \
# 0  6037.0     NaN    ...        0.0    NaN        NaN            NaN
# 1  6037.0     NaN    ...        0.0    NaN        NaN            NaN
# 2  6037.0     NaN    ...        0.0    2.0     1959.0       660680.0
# 3  6037.0     NaN    ...        0.0    NaN     1948.0       580059.0
# 4  6037.0     NaN    ...        0.0    1.0     1947.0       196751.0
#
#    tax_total  assessment_yr  tax_land  tax_bill_ayr  tractblk  tractblk1
# ...

# %%
zwDF2017Short.shape
# Out:
# (2985217, 29)

# %%
zwDF2017Short.count()
# Out:
# parcelid               2985217
# ac_type                 815362
# bath                   2982260
# beds                   2982272
# bldg_qual              1941395
# calc_bath              2868061
# sqft                    203758
# calc_sqft              2940120
# fips                   2982285
# garage                  891008
# lat                    2982285
# lng                    2982285
# lot_sqft               2712511
# pool                    539632
# landuse_id             2982285
# region_city            2923089
# region_cnty            2982285
# region_neighborhood    1156741
# regionzip              2972503
# rooms                  2982248
# units                  1981042
# yearbuilt              2937384
# tax_structure          2938753
# tax_total              2950951
# assessment_yr          2982284
# tax_land               2925291
# tax_bill_ayr           2962465
# tractblk               2910232
# tractblk1              2910232
# dtype: int64

# %%
zwDF2017Short.describe()
# Out:
#            parcelid        ac_type          bath          beds     bldg_qual  \
# count  2.985217e+06  815362.000000  2.982260e+06  2.982272e+06  1.941395e+06
# mean   1.332586e+07       1.945723  2.216196e+00  3.093362e+00  6.280822e+00
# std    7.909966e+06       3.160507  1.078250e+00  1.271569e+00  1.729923e+00
# min    1.071172e+07       1.000000  0.000000e+00  0.000000e+00  1.000000e+00
# 25%    1.164371e+07       1.000000  2.000000e+00  2.000000e+00  5.000000e+00
# 50%    1.254509e+07       1.000000  2.000000e+00  3.000000e+00  6.000000e+00
# 75%    1.409712e+07       1.000000  3.000000e+00  4.000000e+00  8.000000e+00
# max    1.696019e+08      13.000000  3.200000e+01  2.500000e+01  1.200000e+01
#
#           calc_bath           sqft     calc_sqft          fips         garage  \
# count  2.868061e+06  203758.000000  2.940120e+06  2.982285e+06  891008.000000
# mean   2.303826e+00    1379.780460  1.831455e+03  6.048053e+03       1.826581
# ...
