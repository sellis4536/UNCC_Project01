# %%
# Create 10% sample file from zillowDF2017 full file, N=298,522  Column dimension shortened to 28 (dropped duplicate tractblk column at end)
# import libraries, load csv to DF
import pandas as pd
import csv
csvfile = ("Zsample10.csv")
zwsample10DF = pd.read_csv(csvfile)
zwsample10DF.head()
# Out:
#    parcelid  ac_type  bath  beds  bldg_qual  calc_bath  sqft  calc_sqft  fips  \
# 0  14104290        0   1.5     2          0        1.5     0       1008  6059
# 1  12170245        0   1.0     2          6        1.0     0       1500  6037
# 2  17224583        0   3.5     4          0        3.5  1356       3071  6111
# 3  10920939        0   1.0     3          4        1.0     0       1134  6037
# 4  14455839       13   2.0     3          0        2.0     0       1410  6059
#
#    garage      ...       regionzip  rooms  units  yearbuilt  tax_structure  \
# 0       2      ...           97047      5      0       1965          48367
# 1       0      ...           96265      0      1       1948         134826
# 2       2      ...           96385     11      0       1977         450356
# 3       0      ...           96375      0      1       1950         116449
# 4       2      ...           96996      6      0       1970          47884
#
# ...

# %%
zwsample10DF.shape
# Out:
# (298522, 28)

# %%
zwsample10DF.count()
# Out:
# parcelid               298522
# ac_type                298522
# bath                   298522
# beds                   298522
# bldg_qual              298522
# calc_bath              298522
# sqft                   298522
# calc_sqft              298522
# fips                   298522
# garage                 298522
# lat                    298522
# lng                    298522
# lot_sqft               298522
# pool                   298522
# landuse_id             298522
# region_city            298522
# region_cnty            298522
# region_neighborhood    298522
# regionzip              298522
# rooms                  298522
# units                  298522
# yearbuilt              298522
# tax_structure          298522
# tax_total              298522
# assessment_yr          298522
# tax_land               298522
# tax_bill_ayr           298522
# tractblk               298522
# dtype: int64
